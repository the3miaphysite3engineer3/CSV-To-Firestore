# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('God_is_among_us_main.csv')

# %%
df.head()
# Out:
#    ملحوظات             المبلغ موبايل  طريقة التحويل   المنطقة التيكيت   دفع  \
# 0      NaN  انستا باى لميشيل     NaN           250.0      NaN      لا  نعم
# 1      NaN  انستا باى لميشيل     NaN           250.0      NaN      لا  نعم
# 2      NaN  انستا باى لميشيل     NaN           250.0      NaN      لا  نعم
# 3      NaN  انستا باى لميشيل     NaN           250.0      NaN      لا  نعم
# 4      NaN                NaN    NaN           250.0      NaN      لا  نعم
#
#                الاسم   مسلسل Whatsapp
# 0  جيناينان ماجد مكرم    1.0       yes
# 1          نيفين مفيد    2.0       yes
# 2              ماتيوس    3.0       yes
# 3     انجى صبحى سوارس    4.0       yes
# 4       ميشيل صموئيل     5.0       yes

# %%
df.columns
# Out:
# Index(['ملحوظات', 'المبلغ', 'موبايل', 'طريقة التحويل ', 'المنطقة', 'التيكيت',
#        'دفع', 'الاسم ', 'مسلسل', 'Whatsapp '],
#       dtype='object')

# %%
df.columns

# %%
df = df.rename(columns={'ملحوظات': 'Note', 'المبلغ': 'Way of Payment', 'موبايل': 'Mobile', 'طريقة التحويل ': 'Amount', 'المنطقة': 'District', 'التيكيت': 'Ticket', 'دفع': 'Paid', 'الاسم ': 'Name', 'مسلسل': 'ID', 'Whatsapp ': 'Whatsapp', '70000': 'Column_70000', 'رقم الفلوس اللى فى ايدى': 'Money_in_Hand_Notes', 'Unnamed: 12': 'Unnamed_12', '8300': 'Column_8300', '5': 'Column_5', 'Unnamed: 15': 'Unnamed_15', 'Unnamed: 16': 'Unnamed_16', '8000': 'Column_8000'})

# %%
df.shape
# Out:
# (435, 10)

# %%
df.head()
# Out:
#    Note     Way of Payment Mobile  Amount  District Ticket  Paid  \
# 0   NaN  انستا باى لميشيل     NaN   250.0       NaN     لا  نعم
# 1   NaN  انستا باى لميشيل     NaN   250.0       NaN     لا  نعم
# 2   NaN  انستا باى لميشيل     NaN   250.0       NaN     لا  نعم
# 3   NaN  انستا باى لميشيل     NaN   250.0       NaN     لا  نعم
# 4   NaN                NaN    NaN   250.0       NaN     لا  نعم
#
#                  Name   ID Whatsapp
# 0  جيناينان ماجد مكرم  1.0      yes
# 1          نيفين مفيد  2.0      yes
# 2              ماتيوس  3.0      yes
# 3     انجى صبحى سوارس  4.0      yes
# 4       ميشيل صموئيل   5.0      yes

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Note, Way of Payment, Mobile, Amount, District, Ticket, Paid, Name, ID, Whatsapp]
# Index: []

# %%
df.shape
# Out:
# (435, 10)

# %%
df["Attended"] = "No"

# %%
df
# Out:
#      Note     Way of Payment Mobile   Amount  District Ticket  Paid  \
# 0     NaN  انستا باى لميشيل     NaN    250.0       NaN     لا  نعم
# 1     NaN  انستا باى لميشيل     NaN    250.0       NaN     لا  نعم
# 2     NaN  انستا باى لميشيل     NaN    250.0       NaN     لا  نعم
# 3     NaN  انستا باى لميشيل     NaN    250.0       NaN     لا  نعم
# 4     NaN                NaN    NaN    250.0       NaN     لا  نعم
# ..    ...                ...    ...      ...       ...    ...   ...
# 430   NaN                NaN    NaN      NaN       NaN    NaN   NaN
# 431   NaN                NaN    NaN      NaN       NaN    NaN   NaN
# 432   NaN                NaN    NaN      NaN       NaN    NaN   NaN
# 433   NaN                NaN    NaN      NaN       NaN    NaN   NaN
# 434   NaN                NaN    NaN  70000.0       NaN    NaN   NaN
#
#                    Name   ID Whatsapp Attended
# 0    جيناينان ماجد مكرم  1.0      yes       No
# 1            نيفين مفيد  2.0      yes       No
# ...

# %%
df.to_csv("God_is_among_us_edited.csv")
