# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('George.csv')

# %%
df.head()
# Out:
#             Name  ID
# 0    ابانوب اشرف   1
# 1    ابانوب عادل   2
# 2    ابانوب فالح   3
# 3     ابرام صلاح   4
# 4  ارسانيوس ناجى   5

# %%
df.columns
# Out:
# Index(['Name', 'ID'], dtype='object')

# %%
df.columns

# %%
df = df.rename(columns={'مسلسل': "ID", "الاسم": "Name"})

# %%
df.shape
# Out:
# (285, 2)

# %%
df.head()
# Out:
#             Name  ID
# 0    ابانوب اشرف   1
# 1    ابانوب عادل   2
# 2    ابانوب فالح   3
# 3     ابرام صلاح   4
# 4  ارسانيوس ناجى   5

# %%
df.dropna()
# Out:
#                     Name   ID
# 0            ابانوب اشرف    1
# 1            ابانوب عادل    2
# 2            ابانوب فالح    3
# 3             ابرام صلاح    4
# 4          ارسانيوس ناجى    5
# ..                   ...  ...
# 280  يوستينا نبيل باسيلى  281
# 281            يوسف رياض  282
# 282       يوسف نجاح ناجح  283
# 283       يؤانا فتاح عطا  284
# 284           يؤنا مايكل  285
#
# [285 rows x 2 columns]

# %%
df.shape
# Out:
# (285, 2)

# %%
df["Attended"] = "No"

# %%
df
# Out:
#                     Name   ID Attended
# 0            ابانوب اشرف    1       No
# 1            ابانوب عادل    2       No
# 2            ابانوب فالح    3       No
# 3             ابرام صلاح    4       No
# 4          ارسانيوس ناجى    5       No
# ..                   ...  ...      ...
# 280  يوستينا نبيل باسيلى  281       No
# 281            يوسف رياض  282       No
# 282       يوسف نجاح ناجح  283       No
# 283       يؤانا فتاح عطا  284       No
# 284           يؤنا مايكل  285       No
#
# [285 rows x 3 columns]

# %%
df.to_csv("George_edited.csv")
